# %% [markdown]
# <a href="https://colab.research.google.com/github/rishh19/FlyRank-AI-Internship/blob/main/work/notebooks/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import subprocess
import sys

IN_COLAB = "google.colab" in sys.modules

REPO_URL = "https://github.com/rishh19/FlyRank-AI-Internship"
REPO_DIR = "FlyRank-AI-Internship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(
            ["git", "clone", "--depth", "1", REPO_URL, REPO_DIR],
            check=True,
        )
    os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/FlyRank-AI-Internship/FlyRank-AI-Internship

# %%
from google.colab import userdata

HF_TOKEN = userdata.get("HF_TOKEN")

print("HF_TOKEN loaded successfully.")
# Out:
# HF_TOKEN loaded successfully.

# %%
# !pip -q install duckdb huggingface_hub pandas pyarrow scikit-learn

# %%
from huggingface_hub import hf_hub_download

path = hf_hub_download(
    repo_id="FlyRank/internship-warehouse",
    repo_type="dataset",
    filename="fact_content_daily_performance/month=2026-03/data_0.parquet",
    token=HF_TOKEN
)

print(path)
# Out:
# fact_content_daily_performance/month=202(…): reconstructing file:   0%|          |  0.00B /  124MB
# fact_content_daily_performance/month=202(…): downloading bytes:           |  0.00B
# /root/.cache/huggingface/hub/datasets--FlyRank--internship-warehouse/snapshots/50cbf7c3909d07be4d1b5906b4d09e882e5acbf2/fact_content_daily_performance/month=2026-03/data_0.parquet

# %%
import duckdb

con = duckdb.connect()

con.sql(f"""
SELECT *
FROM read_parquet('{path}')
LIMIT 5
""").df()
# Out:
#   report_date           client_hash_id           content_hash_id  \
# 0  2026-03-01  client_73cda7b4e4f265ea  content_b7e512995f79d5a6
# 1  2026-03-01  client_73cda7b4e4f265ea  content_05597932fe4da067
# 2  2026-03-01  client_73cda7b4e4f265ea  content_7a105f548d9c6916
# 3  2026-03-01  client_73cda7b4e4f265ea  content_905aa32a0230694e
# 4  2026-03-01  client_73cda7b4e4f265ea  content_a3ea9792f793ec72
#
#    client_has_gsc  client_has_ga4  gsc_data_available  ga4_data_available  \
# 0            True           False                True                <NA>
# 1            True           False                True                <NA>
# 2            True           False                True                <NA>
# 3            True           False                True                <NA>
# 4            True           False                True                <NA>
#
#    gsc_impressions  gsc_clicks  gsc_sum_position  ...  sessions_ai  \
# ...

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rishh19/FlyRank-AI-Internship/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## Method Choice and Why
#
# I selected a **Decision Tree Classifier** for this modeling task because it is simple to understand, easy to interpret, and works well as a baseline machine learning model. It can learn relationships between search performance signals such as impressions, clicks, and average position to predict whether a content page should be reviewed. I will compare its performance against the rule-based baseline created in Week 4 using the same data and evaluation approach.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Selected Method: Decision Tree Classifier")

features = [
    "gsc_impressions",
    "gsc_clicks",
    "gsc_avg_position"
]

print("\nFeatures used:")
for feature in features:
    print("-", feature)

print("\nReason:")
print("Decision Trees are simple, interpretable, and provide a strong baseline for comparison.")
# Out:
# Selected Method: Decision Tree Classifier
#
# Features used:
# - gsc_impressions
# - gsc_clicks
# - gsc_avg_position
#
# Reason:
# Decision Trees are simple, interpretable, and provide a strong baseline for comparison.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
