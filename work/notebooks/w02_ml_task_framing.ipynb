# %% [markdown]
# <a href="https://colab.research.google.com/github/rishh19/FlyRank-AI-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/rishh19/FlyRank-AI-Internship"
REPO_DIR = "FlyRank-AI-Internship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(
            ["git", "clone", "--depth", "1", REPO_URL, REPO_DIR],
            check=True,
        )
    os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/FlyRank-AI-Internship/FlyRank-AI-Internship

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rishh19/FlyRank-AI-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### 1. My ML Task
#
# I chose the Refresh / Content Opportunity Scoring lane. This is primarily a **scoring** task because the model assigns a priority score to each webpage based on observable signals such as impressions, CTR, content age, and traffic trends. The pages can then be ranked using these scores so that the content team knows which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset loaded successfully.")
print("Total pages:", len(df))
# Out:
# Dataset loaded successfully.
# Total pages: 30000

# %% [markdown]
# ### 2. Target or Proxy
#
# The target of this project is a webpage's refresh priority. As a proxy, the model predicts whether a page is declining based on observable signals. The label comes from the dataset's observed trend direction rather than a manually assigned rule, allowing the model to learn patterns from historical data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Target column:", "is_declining_label")
print("Possible trend categories:")
print(df["trend_direction"].value_counts())
# Out:
# Target column: is_declining_label
# Possible trend categories:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Success Metric
#
# The success metric for this project is Precision@50. This measures how many of the top 50 pages recommended by the model are actually declining. A higher Precision@50 means the recommendations are more useful because the content team spends time reviewing pages that truly need attention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
declining_rate = (df["trend_direction"] == "down").mean()

print(f"Dataset declining rate: {declining_rate:.3f}")
print("Primary evaluation metric: Precision@50")
# Out:
# Dataset declining rate: 0.542
# Primary evaluation metric: Precision@50

# %% [markdown]
# ### 4. Unit of Analysis
#
# The unit of analysis is a single webpage. Each row in the dataset represents one webpage and contains measurable features such as impressions, CTR, content age, average position, and trend information. The model makes one prediction for each webpage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("DataFrame shape:", df.shape)

df.head()
# Out:
# DataFrame shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ### 5. Why ML Beats a Fixed Rule
#
# A fixed rule can only use a small number of conditions and cannot capture complex relationships between multiple signals. Machine learning combines several features such as impressions, CTR, content age, and average position to produce better recommendations. This allows the model to identify important patterns that simple if/else rules may miss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Machine learning combines multiple signals instead of relying on one fixed rule.")
print("Examples: impressions, CTR, content age, average position.")
# Out:
# Machine learning combines multiple signals instead of relying on one fixed rule.
# Examples: impressions, CTR, content age, average position.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
